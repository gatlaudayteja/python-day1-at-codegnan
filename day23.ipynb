# %%
#parent class implementation without using child class implementation
class user:
    def __init__(self, name, email, password):
        self.name = name
        self.email = email
        self.password = password
    def show_info(self):
        return f"name: {self.name} email: {self.email} password: {self.password}"
class admin:
    def __init__(self, name, email, password):
        self.name = name
        self.email = email
        self.password = password
    def show_info(self):
        return f"name: {self.name} email: {self.email} password: {self.password}"
    def total_income(self):
        return f"name: {self.name} and my total income is:{income}"
    def total_users(self):
        return f"i am working as admin and total users are: {total_users}"
income = 100000
total_users = 5000
u1 = user("alice", "gatlaudayteja@gmail.com", "alice123")
u2 = admin("bob", "udayteja1@gmail.com", "bob123")
print(u1.show_info())
print(u2.show_info())
print(u2.total_income())
# Out:
# name: alice email: gatlaudayteja@gmail.com password: alice123
# name: bob email: udayteja1@gmail.com password: bob123
# name: bob and my total income is:100000

# %% [markdown]
# syntax
# class user:
# #attributes
# #methods
# class admin(user):
# #attributes
# #methods

# %%
syntax

# %%
#parent class implementation without using child class implementation
class user:
    def __init__(self, name, email, password):
        self.name = name
        self.email = email
        self.password = password
    def show_info(self):
        return f"name: {self.name} email: {self.email} password: {self.password}"
class admin(user):
    pass
u1 = user("alice", "gatlaudayteja@gmail.com", "alice123")
u2 = admin("bob", "udayteja1@gmail.com", "bob123")
print(u1.show_info())
print(u2.show_info())
# Out:
# name: alice email: gatlaudayteja@gmail.com password: alice123
# name: bob email: udayteja1@gmail.com password: bob123

# %%
#parent class implementation without using child class implementation
class user:
    def __init__(self, name, email, password):
        self.name = name
        self.email = email
        self.password = password
    def show_info(self):
        return f"name: {self.name} email: {self.email} password: {self.password}"
class admin(user):
    def init__(self, name, email, password):
        self.name= name
        self.email = email
        self.password = password
        self.total_users = total_users
    def users(self):
        return f"i am working as admin and total users are: {total_users}"
u1 = user("alice", "gatlaudayteja@gmail.com", "alice123")
u2 = admin("bob", "udayteja1@gmail.com", "bob123")
print(u1.show_info())
print(u2.users())
# Out:
# name: alice email: gatlaudayteja@gmail.com password: alice123
# i am working as admin and total users are: 5000

# %%
#parent class implementation without using child class implementation
class user:
    def __init__(self, name, email, password, age):
        self.name = name
        self.email = email
        self.password = password
    def show_info(self):
        return f"name: {self.name} email: {self.email} password: {self.password} age: {self.age}"
class admin(user):
    def __init__(self, name, email, password, age):
        self.name= name
        self.email = email
        self.password = password
        self.total_users = total_users
    def users(self):
        return f"i am working as admin and total users are: {total_users}"
u1 = user("alice", "gatlaudayteja@gmail.com", "alice123", age=25)
u2 = admin("bob", "udayteja1@gmail.com", "bob123", age=30)
age=25
age=30
print(u1.show_info())
print(u2.users())
print(a1.show_info())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 21
#      19 age=25
#      20 age=30
# ---> 21 print(u1.show_info())
#      22 print(u2.users())
#      23 print(a1.show_info())
#
# Cell In[16], line 8, in user.show_info(self)
#       7 def show_info(self):
# ----> 8     return f"name: {self.name} email: {self.email} password: {self.password} age: {self.age}"
#
# AttributeError: 'user' object has no attribute 'age'

# %% [markdown]
# inheritance
# their are five types
# 1.single level
# 2.multi level
# 3.
